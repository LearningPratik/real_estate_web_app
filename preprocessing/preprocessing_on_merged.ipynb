# %%
import numpy as np
import pandas as pd

import copy

# %%
df = pd.read_csv(r'D:\Projects\plot_recommendition\preprocessed_data\gurgaon_properties.csv')

# %%
df.sample(2)
# Out:
#                         property_name property_type  \
# 1958  3 BHK Flat in Sector 65 Gurgaon          flat
# 631   3 BHK Flat in Sector 65 Gurgaon          flat
#
#                                society  price  price_per_sqft    area  \
# 1958  emaar mgf emerald floors premier   2.55         15454.0  1650.0
# 631                        m3m skycity   3.50         17039.0  2054.0
#
#                                            areaWithType  bedRoom  bathroom  \
# 1958  Super Built up area 1650(153.29 sq.m.)Carpet a...      3.0       3.0
# 631                    Carpet area: 2054 (190.82 sq.m.)      3.0       3.0
#
#      balcony  ...                              address floorNum  facing  \
# 1958       3  ...  Sector 65 Gurgaon, Gurgaon, Haryana      3.0    West
# 631        3  ...  Sector 65 Gurgaon, Gurgaon, Haryana     15.0    East
#
#         agePossession                                    nearbyLocations  \
# 1958  1 to 5 Year Old  ['WorldMark Gurgaon', 'Sohna Road', 'Golf Cour...
# 631   Within 3 months  ['Sector 55 Metro Station', 'Eros City Square'...
#
#                                             description  \
# 1958  Emerald floors premier sector 65\nThis society...
# 631   This lovely 3 bhk apartment/flat in sector 65 ...
#
#                                          furnishDetails  \
# 1958                                                 []
# 631   ['6 Fan', '1 Exhaust Fan', '3 Geyser', '1 Stov...
#
#                                                features  \
# 1958  ['Intercom Facility', 'Lift(s)', 'Maintenance ...
# 631   ['Centrally Air Conditioned', 'Water purifier'...
#
#                                                  rating noOfFloor
# 1958  ['Green Area4.5 out of 5', 'Construction5 out ...       NaN
# 631   ['Environment4 out of 5', 'Lifestyle4 out of 5...       NaN
#
# [2 rows x 21 columns]

# %%
df.shape
# Out:
# (3961, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3961 entries, 0 to 3960
# Data columns (total 21 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   property_name    3961 non-null   object
#  1   property_type    3961 non-null   object
#  2   society          3960 non-null   object
#  3   price            3941 non-null   float64
#  4   price_per_sqft   3941 non-null   float64
#  5   area             3941 non-null   float64
#  6   areaWithType     3961 non-null   object
#  7   bedRoom          3961 non-null   float64
#  8   bathroom         3961 non-null   float64
#  9   balcony          3961 non-null   object
#  10  additionalRoom   3961 non-null   object
#  11  address          3950 non-null   object
#  12  floorNum         2995 non-null   float64
#  13  facing           2784 non-null   object
#  14  agePossession    3960 non-null   object
#  15  nearbyLocations  3754 non-null   object
#  16  description      3961 non-null   object
#  17  furnishDetails   2929 non-null   object
#  18  features         3252 non-null   object
#  19  rating           3511 non-null   object
#  20  noOfFloor        945 non-null    float64
# dtypes: float64(7), object(14)
# memory usage: 650.0+ KB

# %%
df.isnull().sum()
# Out:
# property_name         0
# property_type         0
# society               1
# price                20
# price_per_sqft       20
# area                 20
# areaWithType          0
# bedRoom               0
# bathroom              0
# balcony               0
# additionalRoom        0
# address              11
# floorNum            966
# facing             1177
# agePossession         1
# nearbyLocations     207
# description           0
# furnishDetails     1032
# features            709
# rating              450
# noOfFloor          3016
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.insert(loc=3,column='sector',value=df['property_name'].str.split('in').str.get(1).str.replace('Gurgaon','').str.strip())

# %%
df['sector'] = df['sector'].str.lower()

# %%
df['sector'].value_counts()
# Out:
# sector
# sohna                  163
# sector 102             113
# sector 85              110
# sector 92              104
# sector 69               94
#                       ...
# new jyoti park           1
# kheri                    1
# ashok vihar phase i      1
# sector 17c               1
# begampur khatola         1
# Name: count, Length: 301, dtype: int64

# %%
df['sector'] = df['sector'].str.replace('dharam colony','sector 12')
df['sector'] = df['sector'].str.replace('krishna colony','sector 7')
df['sector'] = df['sector'].str.replace('suncity','sector 54')
df['sector'] = df['sector'].str.replace('prem nagar','sector 13')
df['sector'] = df['sector'].str.replace('mg road','sector 28')
df['sector'] = df['sector'].str.replace('gandhi nagar','sector 28')
df['sector'] = df['sector'].str.replace('laxmi garden','sector 11')
df['sector'] = df['sector'].str.replace('shakti nagar','sector 11')

# %%
df['sector'] = df['sector'].str.replace('baldev nagar','sector 7')
df['sector'] = df['sector'].str.replace('shivpuri','sector 7')
df['sector'] = df['sector'].str.replace('garhi harsaru','sector 17')
df['sector'] = df['sector'].str.replace('imt manesar','manesar')
df['sector'] = df['sector'].str.replace('adarsh nagar','sector 12')
df['sector'] = df['sector'].str.replace('shivaji nagar','sector 11')
df['sector'] = df['sector'].str.replace('bhim nagar','sector 6')
df['sector'] = df['sector'].str.replace('madanpuri','sector 7')

# %%
df['sector'] = df['sector'].str.replace('saraswati vihar','sector 28')
df['sector'] = df['sector'].str.replace('arjun nagar','sector 8')
df['sector'] = df['sector'].str.replace('ravi nagar','sector 9')
df['sector'] = df['sector'].str.replace('vishnu garden','sector 105')
df['sector'] = df['sector'].str.replace('bhondsi','sector 11')
df['sector'] = df['sector'].str.replace('surya vihar','sector 21')
df['sector'] = df['sector'].str.replace('devilal colony','sector 9')
df['sector'] = df['sector'].str.replace('valley view estate','gwal pahari')

# %%
df['sector'] = df['sector'].str.replace('mehrauli  road','sector 14')
df['sector'] = df['sector'].str.replace('jyoti park','sector 7')
df['sector'] = df['sector'].str.replace('ansal plaza','sector 23')
df['sector'] = df['sector'].str.replace('dayanand colony','sector 6')
df['sector'] = df['sector'].str.replace('sushant lok phase 2','sector 55')
df['sector'] = df['sector'].str.replace('chakkarpur','sector 28')
df['sector'] = df['sector'].str.replace('greenwood city','sector 45')
df['sector'] = df['sector'].str.replace('subhash nagar','sector 12')

# %%
df['sector'] = df['sector'].str.replace('sohna road road','sohna road')
df['sector'] = df['sector'].str.replace('malibu town','sector 47')
df['sector'] = df['sector'].str.replace('surat nagar 1','sector 104')
df['sector'] = df['sector'].str.replace('new colony','sector 7')
df['sector'] = df['sector'].str.replace('mianwali colony','sector 12')
df['sector'] = df['sector'].str.replace('jacobpura','sector 12')
df['sector'] = df['sector'].str.replace('rajiv nagar','sector 13')
df['sector'] = df['sector'].str.replace('ashok vihar','sector 3')

# %%
df['sector'] = df['sector'].str.replace('dlf phase 1','sector 26')
df['sector'] = df['sector'].str.replace('nirvana country','sector 50')
df['sector'] = df['sector'].str.replace('palam vihar','sector 2')
df['sector'] = df['sector'].str.replace('dlf phase 2','sector 25')
df['sector'] = df['sector'].str.replace('sushant lok phase 1','sector 43')
df['sector'] = df['sector'].str.replace('laxman vihar','sector 4')
df['sector'] = df['sector'].str.replace('dlf phase 4','sector 28')
df['sector'] = df['sector'].str.replace('dlf phase 3','sector 24')

# %%
df['sector'] = df['sector'].str.replace('sushant lok phase 3','sector 57')
df['sector'] = df['sector'].str.replace('dlf phase 5','sector 43')
df['sector'] = df['sector'].str.replace('rajendra park','sector 105')
df['sector'] = df['sector'].str.replace('uppals southend','sector 49')
df['sector'] = df['sector'].str.replace('sohna','sohna road')
df['sector'] = df['sector'].str.replace('ashok vihar phase 3 extension','sector 5')
df['sector'] = df['sector'].str.replace('south city 1','sector 41')
df['sector'] = df['sector'].str.replace('ashok vihar phase 2','sector 5')

# %%
a = df['sector'].value_counts()[df['sector'].value_counts() >= 3]
df = df[df['sector'].isin(a.index)]

# %%
df['sector'].value_counts()
# Out:
# sector
# sohna road           163
# sector 102           113
# sector 85            110
# sector 92            104
# sector 69             94
#                     ...
# sector 17a             3
# b block sector 43      3
# sector 88b             3
# sector 17b             3
# sector 15              3
# Name: count, Length: 131, dtype: int64

# %%
df['sector'] = df['sector'].str.replace('sector 95a','sector 95')
df['sector'] = df['sector'].str.replace('sector 23a','sector 23')
df['sector'] = df['sector'].str.replace('sector 12a','sector 12')
df['sector'] = df['sector'].str.replace('sector 3a','sector 3')
df['sector'] = df['sector'].str.replace('sector 110 a','sector 110')
df['sector'] = df['sector'].str.replace('patel nagar','sector 15')
df['sector'] = df['sector'].str.replace('a block sector 43','sector 43')
df['sector'] = df['sector'].str.replace('maruti kunj','sector 12')
df['sector'] = df['sector'].str.replace('b block sector 43','sector 43')

# %%
df['sector'] = df['sector'].str.replace('sector-33 sohna road','sector 33')
df['sector'] = df['sector'].str.replace('sector 1 manesar','manesar')
df['sector'] = df['sector'].str.replace('sector 4 phase 2','sector 4')
df['sector'] = df['sector'].str.replace('sector 1a manesar','manesar')
df['sector'] = df['sector'].str.replace('c block sector 43','sector 43')
df['sector'] = df['sector'].str.replace('sector 89 a','sector 89')
df['sector'] = df['sector'].str.replace('sector 2 extension','sector 2')
df['sector'] = df['sector'].str.replace('sector 36 sohna road','sector 36')

# %%
df[df['sector'] == 'new']
# Out:
#                   property_name property_type                       society  \
# 70    4 BHK Flat in New Gurgaon          flat                        dlf 76
# 1066  2 BHK Flat in New Gurgaon          flat                   green court
# 2142  2 BHK Flat in New Gurgaon          flat  takshila heights sector 37 c
# 3601  4 BHK Flat in New Gurgaon          flat                    sare homes
#
#      sector  price  price_per_sqft    area  \
# 70      new   4.00         11428.0  3500.0
# 1066    new   0.38          5507.0   690.0
# 2142    new   0.67          5583.0  1200.0
# 3601    new   0.85          4786.0  1776.0
#
#                                 areaWithType  bedRoom  bathroom  ...  \
# 70          Carpet area: 3500 (325.16 sq.m.)      4.0       4.0  ...
# 1066           Carpet area: 690 (64.1 sq.m.)      2.0       2.0  ...
# 2142  Super Built up area 1200(111.48 sq.m.)      2.0       2.0  ...
# 3601     Super Built up area 1776(165 sq.m.)      4.0       4.0  ...
#
#                             address floorNum facing       agePossession  \
# 70    New Gurgaon, Gurgaon, Haryana      4.0    NaN            Jun 2027
# 1066  New Gurgaon, Gurgaon, Haryana      7.0    NaN  Under Construction
# 2142  New Gurgaon, Gurgaon, Haryana      3.0    NaN     1 to 5 Year Old
# 3601  New Gurgaon, Gurgaon, Haryana      3.0    NaN    5 to 10 Year Old
#
#                                         nearbyLocations  \
# 70    ['Shri Balaji Hospital and Trauma Center', 'S....
# 1066  ['Ing bank ATM', 'Dcb bank ATM', 'Indus ind ba...
# 2142  ['Shri Balaji Hospital and Trauma Center', 'S....
# 3601  ['Columbia Asia Hospital', 'Apex Multi Special...
#
#                                             description  \
# 70    This lovely 4 bhk apartment/flat in new gurgao...
# 1066  We are the proud owners of this 2 bhk apartmen...
# 2142  Check out this 2 bhk apartment for sale in tak...
# 3601  Located in the popular residential address of ...
#
#                                          furnishDetails  \
# 70    ['6 Wardrobe', '1 Fridge', '8 Fan', '1 Exhaust...
# 1066                                                 []
# 2142                                                 []
# 3601                                                 []
#
#                                                features rating noOfFloor
# 70    ['Security / Fire Alarm', 'Feng Shui / Vaastu ...    NaN       NaN
# 1066  ['Intercom Facility', 'Lift(s)', 'Maintenance ...    NaN       NaN
# 2142  ['Lift(s)', 'Swimming Pool', 'Visitor Parking'...    NaN       NaN
# 3601                                                NaN    NaN       NaN
#
# [4 rows x 22 columns]

# %%
df.loc[955,'sector'] = 'sector 37'
df.loc[2800,'sector'] = 'sector 92'
df.loc[2838,'sector'] = 'sector 90'
df.loc[2857,'sector'] = 'sector 76'

# %%
df[df['sector'] == 'new sector 2']
# Out:
#                                     property_name property_type  \
# 4     2 Bedroom House for sale in New Palam Vihar         house
# 1064                2 BHK Flat in New Palam Vihar          flat
# 1314                2 BHK Flat in New Palam Vihar          flat
# 1358                2 BHK Flat in New Palam Vihar          flat
# 2702  3 Bedroom House for sale in New Palam Vihar         house
#
#                   society        sector  price  price_per_sqft    area  \
# 4                 my home  new sector 2   0.34         12592.0   270.0
# 1064  ompee k s residency  new sector 2   1.60         26936.0   594.0
# 1314              my home  new sector 2   0.22          4400.0   500.0
# 1358              my home  new sector 2   0.28          3166.0   884.0
# 2702          independent  new sector 2   1.00          8796.0  1137.0
#
#                                            areaWithType  bedRoom  bathroom  \
# 4                            Plot area 270(25.08 sq.m.)      2.0       2.0
# 1064                      Carpet area: 66 (55.18 sq.m.)      2.0       2.0
# 1314                     Carpet area: 500 (46.45 sq.m.)      2.0       2.0
# 1358                     Carpet area: 900 (83.61 sq.m.)      2.0       1.0
# 2702  Plot area 120(100.34 sq.m.)Built Up area: 120 ...      3.0       2.0
#
#       ...                                            address floorNum facing  \
# 4     ...         Ez-19 A, New Palam Vihar, Gurgaon, Haryana      NaN   West
# 1064  ...                  New Palam Vihar, Gurgaon, Haryana      1.0    NaN
# 1314  ...                  New Palam Vihar, Gurgaon, Haryana      1.0    NaN
# 1358  ...         F 150/b, New Palam Vihar, Gurgaon, Haryana      2.0    NaN
# 2702  ...  Q-148, New Palam Vihar, Phase-2, Near Royal Oa...      NaN  North
#
#          agePossession                                    nearbyLocations  \
# 4     5 to 10 Year Old  ['Palam Vihar Vyapar kendra', 'Palam triangle'...
# 1064   1 to 5 Year Old  ['Palam Vihar Vyapar kendra', 'Palam triangle'...
# 1314   0 to 1 Year Old  ['Palam Vihar Vyapar kendra', 'Palam triangle'...
# 1358   1 to 5 Year Old  ['Palam Vihar Vyapar kendra', 'Palam triangle'...
# 2702      10+ Year Old  ['Palam Vihar Vyapar kendra', 'Palam triangle'...
#
#                                             description  \
# 4     There are availability of various facilities l...
# 1064  We are the proud owners of this 2 bhk apartmen...
# 1314  Cctv surveillance are provided here. There is ...
# 1358  2 bhk room with wooden coverd ,1 drawing room,...
# 2702  Ground and first floor, Ground floor: Ground f...
#
#                                          furnishDetails  \
# 4     ['1 Wardrobe', '3 Fan', '6 Light', 'No AC', 'N...
# 1064                                                NaN
# 1314  ['3 Fan', '1 Exhaust Fan', '15 Light', '1 Modu...
# 1358  ['3 Wardrobe', '5 Light', '1 Chimney', '1 Modu...
# 2702                                                NaN
#
#                                           features  \
# 4     ['Water Storage', 'Park', 'Visitor Parking']
# 1064                                           NaN
# 1314                                           NaN
# 1358                     ['Water Storage', 'Park']
# 2702                                           NaN
#
#                                                  rating noOfFloor
# 4     ['Environment4 out of 5', 'Lifestyle4 out of 5...       3.0
# 1064  ['Environment4 out of 5', 'Safety4 out of 5', ...       NaN
# 1314  ['Safety4 out of 5', 'Lifestyle4 out of 5', 'E...       NaN
# 1358  ['Environment4 out of 5', 'Safety4 out of 5', ...       NaN
# 2702  ['Environment4 out of 5', 'Lifestyle4 out of 5...       1.0
#
# [5 rows x 22 columns]

# %%
df.loc[[311,1072,1486,3040,3875],'sector'] = 'sector 110'

# %%
df.shape
# Out:
# (3803, 22)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3803 entries, 0 to 3960
# Data columns (total 22 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   property_name    3803 non-null   object
#  1   property_type    3803 non-null   object
#  2   society          3802 non-null   object
#  3   sector           3803 non-null   object
#  4   price            3785 non-null   float64
#  5   price_per_sqft   3785 non-null   float64
#  6   area             3785 non-null   float64
#  7   areaWithType     3803 non-null   object
#  8   bedRoom          3803 non-null   float64
#  9   bathroom         3803 non-null   float64
#  10  balcony          3803 non-null   object
#  11  additionalRoom   3803 non-null   object
#  12  address          3794 non-null   object
#  13  floorNum         2941 non-null   float64
#  14  facing           2698 non-null   object
#  15  agePossession    3802 non-null   object
#  16  nearbyLocations  3626 non-null   object
#  17  description      3803 non-null   object
#  18  furnishDetails   2822 non-null   object
#  19  features         3168 non-null   object
#  20  rating           3462 non-null   object
#  21  noOfFloor        843 non-null    float64
# dtypes: float64(7), object(15)
# memory usage: 812.4+ KB

# %%
df.sample(2)
# Out:
#                                       property_name property_type  \
# 2750  6 Bedroom House for sale in Sector 31 Gurgaon         house
# 1001                3 BHK Flat in Sector 92 Gurgaon          flat
#
#                         society     sector  price  price_per_sqft    area  \
# 2750  huda housing board colony  sector 31   4.60         31506.0  1460.0
# 1001   signature global city 92  sector 92   0.99          9074.0  1091.0
#
#                             areaWithType  bedRoom  bathroom  ...  \
# 2750        Plot area 1460(135.64 sq.m.)      6.0       4.0  ...
# 1001  Built Up area: 1091 (101.36 sq.m.)      3.0       2.0  ...
#
#                                         address floorNum facing  \
# 2750  Xxxx, Sector 31 Gurgaon, Gurgaon, Haryana      NaN   East
# 1001        Sector 92 Gurgaon, Gurgaon, Haryana      1.0    NaN
#
#       agePossession                                    nearbyLocations  \
# 2750   10+ Year Old  ['Rajiv Chowk Mosque', 'Hanuman Mandir', 'Icic...
# 1001       Dec 2024  ['Iris Broadway Mall', 'Pataudi Road', 'Dwarka...
#
#                                             description  \
# 2750        Sec 31 main market near school hospital nh8
# 1001  Best in class property available at sector 92 ...
#
#                                          furnishDetails  \
# 2750                                                NaN
# 1001  ['5 Light', '1 Modular Kitchen', 'No AC', 'No ...
#
#                                                features  \
# 2750                                           ['Park']
# 1001  ['Lift(s)', 'Swimming Pool', 'Park', 'Fitness ...
#
#                                                  rating noOfFloor
# 2750  ['Environment5 out of 5', 'Lifestyle5 out of 5...       3.0
# 1001  ['Environment5 out of 5', 'Lifestyle4 out of 5...       NaN
#
# [2 rows x 22 columns]

# %%
# features to drop -> property_name, address, description, rating
df.drop(columns=['property_name', 'address', 'description', 'rating'],inplace=True)

# %%
df.sample(5)
# Out:
#      property_type               society     sector  price  price_per_sqft  \
# 2324          flat  sunischit apartments  sector 54   1.75          7954.0
# 1920         house    eros rosewood city  sector 49   1.60         31481.0
# 2040         house           independent  sector 57   3.15         20349.0
# 1668         house           independent   sector 4   0.47         10601.0
# 2416         house          malibu towne  sector 47   8.81         27191.0
#
#         area                                       areaWithType  bedRoom  \
# 2324  2200.0  Super Built up area 2200(204.39 sq.m.)Built Up...      3.0
# 1920   508.0                          Plot area 60(50.17 sq.m.)      4.0
# 2040  1548.0                        Plot area 172(143.81 sq.m.)      5.0
# 1668   443.0  Plot area 49(40.97 sq.m.)Built Up area: 50 sq....      2.0
# 2416  3240.0                        Plot area 360(301.01 sq.m.)      8.0
#
#       bathroom balcony                  additionalRoom  floorNum      facing  \
# 2324       3.0      3+                    servant room       6.0  North-East
# 1920       4.0       3                   not available       NaN        East
# 2040       4.0      3+                      store room       NaN  North-East
# 1668       2.0       1                      study room       NaN        East
# 2416       6.0      3+  study room,servant room,others       NaN        East
#
#          agePossession                                    nearbyLocations  \
# 2324  5 to 10 Year Old  ['Sector metro station', 'Sector metro station...
# 1920   0 to 1 Year Old  ['Sri Radhe Krishna Temple', 'Standard charter...
# 2040  5 to 10 Year Old  ['Radhakrishna Shani Mandir', 'Sanatan Dharm M...
# 1668   0 to 1 Year Old  ['Dev Man Kathuria Clinic', 'Dr. Madan Clinic'...
# 2416  5 to 10 Year Old  ['Standard chartered ATM', 'Icici bank ATM', '...
#
#                                          furnishDetails  \
# 2324  ['4 Fan', '1 Exhaust Fan', '3 Geyser', '24 Lig...
# 1920  ['1 Wardrobe', '1 Fan', '1 Exhaust Fan', '1 Ge...
# 2040  ['3 Wardrobe', '8 Fan', '30 Light', '1 Modular...
# 1668  ['1 Wardrobe', '4 Fan', '1 Exhaust Fan', '10 L...
# 2416  ['13 Fan', '7 Geyser', '7 Light', '2 Chimney',...
#
#                                                features  noOfFloor
# 2324  ['Security / Fire Alarm', 'Feng Shui / Vaastu ...        NaN
# 1920  ['Feng Shui / Vaastu Compliant', 'Water Storag...        4.0
# 2040  ['High Ceiling Height', 'False Ceiling Lightin...        2.0
# 1668  ['Feng Shui / Vaastu Compliant', 'Private Gard...        2.0
# 2416  ['Maintenance Staff', 'Water Storage', 'Visito...        3.0

# %%
df.duplicated().sum()
# Out:
# np.int64(122)

# %%
df.to_csv('gurgaon_properties_cleaned_v1.csv',index=False)
