# %%
import numpy as np
import pandas as pd

# %%
flats = pd.read_csv('flats_cleaned.csv')
houses = pd.read_csv('house_cleaned.csv')

# %%
df = pd.concat([flats,houses],ignore_index=True)

# %%
df = df.sample(df.shape[0],ignore_index=True)

# %%
df.head()
# Out:
#                                  property_name property_type  \
# 0             3 BHK Flat in Sector 67A Gurgaon          flat
# 1              3 BHK Flat in Sector 69 Gurgaon          flat
# 2              3 BHK Flat in Sector 80 Gurgaon          flat
# 3             4 BHK Flat in Sector 103 Gurgaon          flat
# 4  2 Bedroom House for sale in New Palam Vihar         house
#
#                    society  price  price_per_sqft    area  \
# 0       ireo the corridors   1.62          9380.0  1727.0
# 1             tulip violet   1.43          8886.0  1609.0
# 2          godrej frontier   1.60          7000.0  2286.0
# 3  indiabulls centrum park   2.45          8521.0  2875.0
# 4                  my home   0.34         12592.0   270.0
#
#                                         areaWithType  bedRoom  bathroom  \
# 0  Super Built up area 1727(160.44 sq.m.)Carpet a...      3.0       3.0
# 1             Super Built up area 1608(149.39 sq.m.)      3.0       3.0
# 2             Super Built up area 2262(210.15 sq.m.)      3.0       3.0
# 3              Super Built up area 2875(267.1 sq.m.)      4.0       4.0
# 4                         Plot area 270(25.08 sq.m.)      2.0       2.0
#
#   balcony  ...                                     address floorNum  \
# 0       2  ...   000, Sector 67A Gurgaon, Gurgaon, Haryana      4.0
# 1       2  ...         Sector 69 Gurgaon, Gurgaon, Haryana      1.0
# 2       3  ...         Sector 80 Gurgaon, Gurgaon, Haryana      5.0
# 3       3  ...  1564, Sector 103 Gurgaon, Gurgaon, Haryana     11.0
# 4       2  ...  Ez-19 A, New Palam Vihar, Gurgaon, Haryana      NaN
#
#        facing     agePossession  \
# 0       North   0 to 1 Year Old
# 1  North-West   1 to 5 Year Old
# 2         NaN  5 to 10 Year Old
# 3        East   1 to 5 Year Old
# 4        West  5 to 10 Year Old
#
#                                      nearbyLocations  \
# 0  ['Huda Metro Station (Gurugram)', 'Paras Trini...
# 1  ['Airia Mall Sector 68', 'Southern Peripheral ...
# 2  ['Pooja Clinic', 'Dr. Sahil Clinic', 'Prakash ...
# 3  ['Gurgaon Dreamz Mall', 'HUDA Market, Sector 1...
# 4  ['Palam Vihar Vyapar kendra', 'Palam triangle'...
#
#                                          description  \
# 0  Brokers please excuse\n3 bhk +store room resid...
# 1  This beautiful 3 bhk flat in sector 69 gurgaon...
# 2  This 3 bhk flat in sector-80 gurgaon, gurgaon ...
# 3  Indiabulls centrum park is one of gurgaon's mo...
# 4  There are availability of various facilities l...
#
#                                       furnishDetails  \
# 0  ['3 Wardrobe', '1 Water Purifier', '4 Fan', '1...
# 1  ['1 Modular Kitchen', 'No AC', 'No Bed', 'No C...
# 2                                                 []
# 3  ['1 Modular Kitchen', 'No AC', 'No Bed', 'No C...
# 4  ['1 Wardrobe', '3 Fan', '6 Light', 'No AC', 'N...
#
#                                             features  \
# 0  ['Water purifier', 'Security / Fire Alarm', 'P...
# 1  ['Power Back-up', 'Feng Shui / Vaastu Complian...
# 2  ['Intercom Facility', 'Lift(s)', 'Maintenance ...
# 3  ['Lift(s)', 'Swimming Pool', 'Park', 'Shopping...
# 4       ['Water Storage', 'Park', 'Visitor Parking']
#
#                                               rating noOfFloor
# 0  ['Environment5 out of 5', 'Lifestyle4 out of 5...       NaN
# 1  ['Green Area5 out of 5', 'Construction4 out of...       NaN
# 2  ['Management3 out of 5', 'Green Area4 out of 5...       NaN
# 3  ['Green Area5 out of 5', 'Construction4 out of...       NaN
# 4  ['Environment4 out of 5', 'Lifestyle4 out of 5...       3.0
#
# [5 rows x 21 columns]

# %%
df.to_csv('gurgaon_properties.csv',index=False)
